# %% [markdown]
# | Big-O        | Name          | Analogy / Example                                      |
# | ------------ | ------------- | ------------------------------------------------------ |
# | `O(1)`       | Constant Time | Pick the first item from a box                         |
# | `O(log n)`   | Logarithmic   | Binary search in a sorted list                         |
# | `O(n)`       | Linear Time   | Look at every item once                                |
# | `O(n log n)` | Linearithmic  | Efficient sorting like Merge Sort or Quick Sort        |
# | `O(n^2)`     | Quadratic     | Nested loops - compare every pair                      |
# | `O(2^n)`     | Exponential   | Subset generation (e.g. recursive Fibonacci)           |
# | `O(n!)`      | Factorial     | All possible arrangements (e.g. permutations of items) |

# %% [markdown]
# # 📌 Example for Your Practice
# Q: What is the time complexity of this code?

# %% [markdown]
# ### O(n) — one loop

# %%
n = 2
for i in range(n):
    print(i)
# Out:
# 0
# 1

# %% [markdown]
# ### O(n²) — nested loop

# %%
n = 2
for i in range(n):
    for j in range(n):
        print(i, j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1

# %% [markdown]
# ### O(1) — constant

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ### # O(log n) — binary search

# %%
def binary_search(arr, x):
    l, r = 0, len(arr)-1
    while l <= r:
        mid = (l + r) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            l = mid + 1
        else:
            r = mid - 1

# %%
binary_search([1,2,3,4,5], 4)
# Out:
# 3

# %%
def bin_ser(arr, x):
    l, r = 0, len(arr) - 1
    while l <= r:
        mid = (l+r) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            l = mid + 1
        else:
            l = mid - 1
bin_ser([1,2,3,4], 3)
# Out:
# 2

# %%
def checkOddEven(x):
    if x % 2 == 0:
        # Complete the statement below
        return True

    elif x % 2 != 0:
        return "Odd"
checkOddEven(1)
# Out:
# 'Odd'

# %%
n1 = int(input())
n2 = int(input())

differences = []
for i in range(1, 11):
    diff = (n1*i) - (n2*i)
    differences.append(diff)
print(" ".join(map(str, differences)))
# Out:
# 5 10 15 20 25 30 35 40 45 50

# %%
# Print Squae Wall
n = int(input())
for i in range(n):
    for j in range(n):
        print("*", end=" ")
    print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
5//2
# Out:
# 2

# %%
2 + 3 * 4 / 2
# Out:
# 8.0

# %%
str = "GFG"
print(not (not(str and "")))
# Out:
# False

# %%
print(oct(23)+oct(23))
# Out:
# 0o270o27

# %%
print((~(~2)))
# Out:
# 2

# %%
10 > 5 and 5 < 3
# Out:
# False

# %%
class Solution:
    def calculate(self, a: int, b: int, c: int, d:int) -> int:
        # Code Here
        soln = (a+b) // c + d
        return soln
s = Solution()
s.calculate(10,4,7,9)
# Out:
# 11

# %%
x = input()
y = input()
print(x+5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 x = input()
#       2 y = input()
# ----> 3 print(x+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = int(input())
print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 x = int(input())
#       2 print(x)
#
# ValueError: invalid literal for int() with base 10: '1.3'

# %%
(1+2j) * (3+4j)
# Out:
# (-5+10j)

# %%
10%3
# Out:
# 1

# %%
1_000_000_4 + 1
# Out:
# 10000005

# %%
import math
math.log2(16)
# Out:
# 4.0

# %%
math.log(16,2)
# Out:
# 4.0

# %%
bool(0)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
not True
# Out:
# False

# %%
bool(0) and bool(1)
# Out:
# False

# %%
False and not False
# Out:
# False

# %%
all([True, True, False])
# Out:
# False

# %%
not any([False, False, False])
# Out:
# True
