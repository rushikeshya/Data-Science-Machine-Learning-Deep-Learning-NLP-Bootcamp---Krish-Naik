# %% [markdown]
# # Exception Handling

# %% [markdown]
# - Exception handlling in python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program.
# - This lesson will cover the basics of exceptions, including how to use try, except, else, and finally block.

# %% [markdown]
# # What are Exceptions?
#  Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#  - ZeroDivisionError: Dividing by zero
#  - FileNotFoundError:File not found
#  - ValueError: Invalid value.
#  - TypeError: Invalid type

# %%
## Exception try, except block

try:
    a = b
except:
    print("B variable has not been decleared!")
# Out:
# B variable has not been decleared!

# %%
try:
    a = b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result = 1/2
    print(result)
except:
    print("Number cannot be divided by ZERO!")
# Out:
# 0.5

# %%
try:
    result = 1/00.00
    print(result)
except:
    print("Number cannot be divided by ZERO!")
# Out:
# Number cannot be divided by ZERO!

# %%
try:
    result = 1/0
    print(result)
except ZeroDivisionError as zero:
    print(f"Error: {zero}")
    print("Please Enter the Denominator Greater than the ZERO (0)")
# Out:
# Error: division by zero
# Please Enter the Denominator Greater than the ZERO (0)

# %%
try:
    result = 1/2
    print(result)
    a=c
except ZeroDivisionError as zero:
    print(f"Error: {zero}")
    print("Please Enter the Denominator Greater than the ZERO (0)")
# Out:
# 0.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2     result = 1/2
#       3     print(result)
# ----> 4     a=c
#       5 except ZeroDivisionError as zero:
#       6     print(f"Error: {zero}")
#
# NameError: name 'c' is not defined

# %%
try:
    result = 1/2
    print(result)
    a=b
except ZeroDivisionError as zero:
    print(zero)
    print("Please Enter the Denominator Greater than 0")
except Exception as ex1:
    print(ex1)
    print("Main exception got caught")
# Out:
# 0.5
# name 'b' is not defined
# Main exception got caught

# %%
# 10:01
try:
    num = int(input("Enter a number"))
    result = 10/num
    print(result)
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError as error:
    print(error)
    print("Number can not be divisible by 0")
except Exception as ex:
    print(ex)
# Out:
# This is not a valid number

# %% [markdown]
# ## try, except, else block

# %%
try:
    num = int(input("Enter a number: "))
    result = 10/num
except NameError:
    print("That's not a valid number!")
except ZeroDivisionError:
    print("You can't divide by zero!")
except Exception as ex:
    print(ex)
    print("Error caught from this Exception Class")

else:
    print(f"the result is {result:.2f}")
# Out:
# invalid literal for int() with base 10: 'dfdfd'
# Error caught from this Exception Class

# %% [markdown]
# # try, except, and finnaly

# %%
try:
    num = int(input("Enter a number: "))
    result = 10/num
except NameError:
    print("That's not a valid number!")
except ZeroDivisionError:
    print("You can't divide by zero!")
except Exception as ex:
    print(ex)
    print("Error caught from this Exception Class")
else:
    print(f"the result is {result:.2f}")
finally:
    print("Execution complete.")
# Out:
# the result is 2.00
# Execution complete.

# %% [markdown]
# ## try, except, else, and finnaly

# %%
try:
    num = int(input("Enter a number: "))
    result = 10/num
except NameError:
    print("That's not a valid number!")
except ZeroDivisionError:
    print("You can't divide by zero!")
except Exception as ex:
    print(ex)
    print("Error caught from this Exception Class")
else:
    print(f"the result is {result:.2f}")
finally:
    print("Execution complete.")
# Out:
# You can't divide by zero!
# Execution complete.

# %% [markdown]
# # File handling and Exception Handling

# %%
try:
    file = open('example.txt','r')
    content = file.read()
    a=b
    print(content)
except FileNotFoundError as filenot:
    print(filenot)
    print("The file does not exists")
except Exception as ex:
    print(ex)


finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print('file closed')
# Out:
# name 'b' is not defined
# file closed
