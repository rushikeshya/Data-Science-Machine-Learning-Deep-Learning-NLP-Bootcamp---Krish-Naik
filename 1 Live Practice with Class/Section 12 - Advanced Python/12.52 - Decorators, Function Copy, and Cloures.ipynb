# %% [markdown]
# # Decorators
# - Decorators are a powerful and flexible feature in Python  that allows us to modify the behavior of a function or class method. They are commonly used to add functionality or methods without modifying their actual code. This lesson covers the basic of decorators, including how to creat and use them.
#
# ## function copy
# ## closures
# ## decorators

# %% [markdown]
# ## Function Copy

# %%
def welcome():
    return "Welcome to the Advanced Python Course"

# %%
wel = welcome  # Function copy
wel
# Out:
# <function __main__.welcome()>

# %%
wel()
# Out:
# 'Welcome to the Advanced Python Course'

# %%
del welcome # even we deleted welcome function .....

# %%
wel()  # we have copied welcome function already in `wel`
# Out:
# 'Welcome to the Advanced Python Course'

# %%
type(wel)
# Out:
# function

# %% [markdown]
# # Clousures functions-
# - function inside function

# %%
def main_welcome():
    msg = "Welcome"
    def sub_welcome_method():
        print("Welcome to the advance python course")

        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome()
# Out:
# Welcome to the advance python course
# Please learn these concepts properly

# %%
def main_welcome():
    msg = "Welcome"
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(msg)
        print("Please learn these concepts properly")
    return sub_welcome_method()
main_welcome()
# Out:
# Welcome to the advance python course
# Welcome
# Please learn these concepts properly

# %%
def main_welcome(msg):
    #msg = "Welcome"
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(msg)
        print("Please learn these concepts properly")
    return sub_welcome_method()
main_welcome("Welcome everyone!")
# Out:
# Welcome to the advance python course
# Welcome everyone!
# Please learn these concepts properly

# %%
def main_welcome(func):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        func("Welllllllllll")
        print("Please learn these concepts properly")
    return sub_welcome_method()
main_welcome(print)
# Out:
# Welcome to the advance python course
# Welllllllllll
# Please learn these concepts properly

# %%
def main_welcome(func):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(func("Hello"))
        print("Please learn these concepts properly")
    return sub_welcome_method()
main_welcome(len)
# Out:
# Welcome to the advance python course
# 5
# Please learn these concepts properly

# %%
def main_welcome(func,lst):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(func(lst))
        print("Please learn these concepts properly")
    return sub_welcome_method()
main_welcome(len, [1,2,3,4,5,])
# Out:
# Welcome to the advance python course
# 5
# Please learn these concepts properly

# %% [markdown]
# ### Decorators:

# %%
def main_welcome(func):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        func()
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
def course_introduction():
    print("This is an advanced python course.")
    
course_introduction()
# Out:
# This is an advanced python course.

# %%
main_welcome(course_introduction)
# Out:
# Welcome to the advance python course
# This is an advanced python course.
# Please learn these concepts properly

# %%
# decorators
@main_welcome      # Decorators
def course_introduction():
    print("This is an advanced python course.")
# Out:
# Welcome to the advance python course
# This is an advanced python course.
# Please learn these concepts properly

# %%
# Example 2
def my_decorators(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper()

# %%
@my_decorators
def sample():
    print("This my_decorators successfully ran!")
# Out:
# Something is happening before the function is called.
# This my_decorators successfully ran!
# Something is happening after the function is called.

# %% [markdown]
# ## Decorators with arguments

# %%
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print("Hello")
say_hello()
# Out:
# Hello
# Hello
# Hello

# %% [markdown]
# # Conclusion:
# - Decorators are a powerful tool in Python for extending and modifying the behavior of functions and methods.
# - They provide a clean and readable way to add functionality such as logging, timing, access control, and more without changine the original code. Understanding and using decorators effectively can significantly enhance our Python Programming skills.
